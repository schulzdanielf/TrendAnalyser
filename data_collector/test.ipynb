# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta
import psycopg2
import database

# %%
def not_contains_query(query, title, description):
    """Verifica se a consulta não está no título ou descrição."""
    for word in query.lower().split(' '):
        if word in title.lower() or word in description.lower():
            return False
    print("Não contém a consulta: ", query, title, description)
    return True


def fetch_g1_news(query, num_articles=5):
    """Obtém notícias do site G1 com base em uma consulta."""

    base_url = f'https://g1.globo.com/busca/?q={query.replace(" ", "+")}&order=recent&species=notícias'
    articles = []
    page = 1

    while len(articles) < num_articles:
        url = f'{base_url}&page={page}'
        response = requests.get(url)

        if response.status_code != 200:
            print(f"Erro ao acessar o site: {response.status_code}")
            break

        soup = BeautifulSoup(response.text, 'html.parser')

        # Encontre os blocos de notícia
        for item in soup.find_all('li', class_='widget widget--card widget--info'):
            title_tag = item.find('div', class_='widget--info__title')
            link_tag = item.find('a', href=True)
            date_tag = item.find('div', class_='widget--info__meta')
            description_tag = item.find('p', class_='widget--info__description')

            if title_tag and link_tag:
                title = title_tag.get_text(strip=True)
                link = fetch_final_link(link_tag['href'])
                date = date_tag.get_text(strip=True) if date_tag else 'Desconhecida'
                description = description_tag.get_text(strip=True) if description_tag else 'Sem descrição'


                # Se a consulta não estiver no título ou descrição, pule
                if not_contains_query(query, title, description):
                    print("Pulando: ", title)
                    continue

                # Extrai o texto completo da notícia
                full_text = fetch_news_text(link)

                # Adiciona os dados ao resultado
                articles.append({
                    'title': title,
                    'link': link,
                    'date': date,
                    'description': description,
                    'full_text': full_text
                })

                # Parar se já tiver o número desejado de artigos
                if len(articles) >= num_articles:
                    break

        # Avança para a próxima página
        page += 1

    articles_df = pd.DataFrame(articles)
    articles_df = ajusta_data(articles_df)

    articles_df['candidate'] = query

    return articles_df
# Out:
#   Cell In[59], line 13
#     base_url = f'https://g1.globo.com/busca/?q={query.replace(' ', '+')}&order=recent&species=notícias'
#                                                                     ^
# SyntaxError: f-string: unmatched '('

# %%
def fetch_final_link(link):
    """Obtém o link final de uma notícia."""
    if not link.startswith('http'):
        link = f'https:{link}'
    response = requests.get(link)
    if response.status_code != 200:
        print(f"Erro ao acessar o link da notícia: {response.status_code}")

    link_final = response.text.split('window.location.replace("')[1].split('");')[0]

    return link_final

# %%
def fetch_news_text(news_link):
    """Obtém o texto completo de uma notícia a partir do link."""
    if not news_link.startswith('http'):
        news_link = f'https:{news_link}'
    
    response = requests.get(news_link)
    
    if response.status_code != 200:
        print(f"Erro ao acessar o link da notícia: {response.status_code}")
        return 'Texto não disponível'
    # salvar o html
    with open('g1.html', 'w') as file:
        file.write(response.text)

    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Ajuste o seletor de acordo com a estrutura da página de notícia
    text_container = soup.find('p', class_='content-text__container')  # Exemplo de seletor
    full_text = ''
    if text_container:
        # For loop para pegar todos os p e a tag de texto
        for text in text_container:
            # concatenate the text
            full_text += text.get_text()
        return full_text
    else:
        return ''

# %%
def store_news(articles):
    """Armazena os dados das notícias no banco de dados PostgreSQL."""
    conn = database.connect_to_database()
    cursor = conn.cursor()

    for index, row in articles.iterrows():
        title = row['title']
        link = row['link']
        date = row['date']
        description = row['description']
        full_text = row['full_text']

        try:
            cursor.execute(
                "INSERT INTO news (title, link, date, description, full_text) VALUES (%s, %s, %s, %s, %s)",
                (title, link, date, description, full_text)
            )
        except Exception as e:
            print(f"Erro ao inserir notícia no banco de dados: {e}")

    conn.commit()
    cursor.close()
    conn.close()

# %%
store_news(news_articles_df)
# Out:
# Erro ao conectar-se ao banco de dados: could not translate host name "db" to address: Name or service not known
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 store_news(news_articles_df)
#
# Cell In[38], line 4, in store_news(articles)
#       2 """Armazena os dados das notícias no banco de dados PostgreSQL."""
#       3 conn = database.connect_to_database()
# ----> 4 cursor = conn.cursor()
#       6 for index, row in articles.iterrows():
#       7     title = row['title']
#
# AttributeError: 'NoneType' object has no attribute 'cursor'

# %%
db_params = {
    'host': 'my_postgres',
    'database': 'mydatabase',
    'user': 'myuser',
    'password': 'mypassword',
    'port': 5432
}

# Busca notícias relacionadas a "Tabata Amaral"
query = 'Tabata Amaral'
news_articles = fetch_g1_news(query, num_articles=20)

print(f"Encontradas {len(news_articles)} notícias sobre {query}")

news_articles
# Out:
# 2024-08-08 15:01:07.722156
# 2024-08-05 14:54:00
# 2024-08-05 21:23:00
# 2024-08-05 18:40:00
# 2024-08-05 21:38:00
# 2024-08-05 14:17:00
# 2024-08-05 15:28:00
# 2024-08-06 15:22:00
# 2024-08-06 00:13:00
# 2024-08-05 15:38:00
# 2024-08-05 15:24:00
# 2024-08-05 14:29:00
# 2024-08-05 14:22:00
# 2024-08-05 15:25:00
# 2024-08-05 13:42:00
# Encontradas 15 notícias sobre Tabata Amaral
#                                                 title  \
# 0   Natuza Nery entrevista Tabata Amaral (PSB); ve...
# 1                     Tabata Amaral fala sobre aborto
# 2   VÍDEOS: Natuza Nery entrevista Tabata Amaral (...
# 3          Natuza Nery entrevista Tabata Amaral (PSB)
# 4   O Assunto #1271: Natuza Nery entrevista Tabata...
# 5     Tabata Amaral responde sobre votos na periferia
# 6   Tabata Amaral (PSB) responde pergunta sobre Sa...
# 7   José Luiz Datena (PSDB) responde a pergunta so...
# 8   Veja o que é #FATO ou #FAKE na entrevista de T...
# 9   Tabata Amaral (PSB) responde a pergunta sobre ...
# 10  Tabata Amaral (PSB) responde a pergunta sobre ...
# 11  Tabata Amaral (PSB) responde a pergunta sobre ...
# 12  Tabata Amaral (PSB) responde a pergunta sobre ...
# 13  Tabata Amaral (PSB) responde a pergunta sobre ...
# 14  Tabata Amaral (PSB) responde a pergunta sobre ...
#
#                                                  link  \
# 0   https://g1.globo.com/sp/sao-paulo/eleicoes/202...
# 1   https://g1.globo.com/politica/eleicoes/2022/vi...
# 2   https://g1.globo.com/podcast/o-assunto/playlis...
# 3   https://g1.globo.com/podcast/o-assunto/ao-vivo...
# 4   https://g1.globo.com/podcast/o-assunto/noticia...
# 5   https://g1.globo.com/politica/eleicoes/2022/vi...
# 6   https://g1.globo.com/politica/eleicoes/2022/vi...
# 7   https://g1.globo.com/politica/eleicoes/2022/vi...
# 8   https://g1.globo.com/fato-ou-fake/sao-paulo/no...
# 9   https://g1.globo.com/politica/eleicoes/2022/vi...
# 10  https://g1.globo.com/politica/eleicoes/2022/vi...
# 11  https://g1.globo.com/politica/eleicoes/2022/vi...
# 12  https://g1.globo.com/politica/eleicoes/2022/vi...
# 13  https://g1.globo.com/politica/eleicoes/2022/vi...
# 14  https://g1.globo.com/politica/eleicoes/2022/vi...
#
#                           date  \
# 0   2024-08-08 15:01:07.722156
# 1          2024-08-05 14:54:00
# 2          2024-08-05 21:23:00
# 3          2024-08-05 18:40:00
# 4          2024-08-05 21:38:00
# 5          2024-08-05 14:17:00
# 6          2024-08-05 15:28:00
# 7          2024-08-06 15:22:00
# 8          2024-08-06 00:13:00
# 9          2024-08-05 15:38:00
# 10         2024-08-05 15:24:00
# 11         2024-08-05 14:29:00
# 12         2024-08-05 14:22:00
# 13         2024-08-05 15:25:00
# 14         2024-08-05 13:42:00
#
#                                           description  \
# 0   O Assunto: Natuza Nery entrevistaTabataAmaral(...
# 1   Série do g1 começa na segunda (5) com a candid...
# 2
# 3   Natuza Nery entrevistaTabataAmaral(PSB) Esta s...
# 4   ... sobre traição de DatenaTabataAmaralanuncia...
# 5   Série do g1 começa na segunda (5) com a candid...
# 6   Série do g1 começa na segunda (5) com a candid...
# 7   Série do g1 começou na segunda (5) comTabataAm...
# 8   TabataAmaral(PSB), candidata à Prefeitura de S...
# 9   Série do g1 começa na segunda (5) com a candid...
# 10  Série do g1 começa na segunda (5) com a candid...
# 11  Série do g1 começa na segunda (5) com a candid...
# 12  Série do g1 começa na segunda (5) com a candid...
# 13  Série do g1 começa na segunda (5) com a candid...
# 14  Série do g1 começa na segunda (5) com a candid...
#
#                                             full_text
# 0    A deputada federal Tabata Amaral, candidata à...
# 1
# 2
# 3
# 4    Você pode ouvir O Assunto no g1, no GloboPlay...
# 5
# 6
# 7
# 8    A deputada federal Tabata Amaral, candidata à...
# 9
# 10
# 11
# 12
# 13
# 14

# %%
news_articles_df = pd.DataFrame(news_articles)
print(news_articles_df['date'][0])
news_articles_df['date'][1]
# Out:
# há 5 dias
# '05/08/2024 14h54'

# %%
news_articles_df['date'][0][3]
# Out:
# '5'

# %%
def ajusta_data(df):
    for i in range(len(df)):
        if df['date'][i][:2] == 'há':
            df['date'][i] = datetime.now() - timedelta(days=int(df['date'][i][3]))
        else:
            # convert this format 05/08/2024 14h54 to datetime
            df['date'][i] = datetime.strptime(df['date'][i], "%d/%m/%Y %Hh%M")
    return df

# %%
news_articles_df
# Out:
#                                                title  \
# 0  Natuza Nery entrevista Tabata Amaral (PSB); ve...
# 1                    Tabata Amaral fala sobre aborto
# 2  VÍDEOS: Natuza Nery entrevista Tabata Amaral (...
# 3         Natuza Nery entrevista Tabata Amaral (PSB)
# 4  O Assunto #1271: Natuza Nery entrevista Tabata...
# 5    Tabata Amaral responde sobre votos na periferia
# 6  Tabata Amaral (PSB) responde pergunta sobre Sa...
# 7  José Luiz Datena (PSDB) responde a pergunta so...
# 8  Veja o que é #FATO ou #FAKE na entrevista de T...
# 9  Tabata Amaral (PSB) responde a pergunta sobre ...
#
#                                                 link  \
# 0  https://g1.globo.com/sp/sao-paulo/eleicoes/202...
# 1  https://g1.globo.com/politica/eleicoes/2022/vi...
# 2  https://g1.globo.com/podcast/o-assunto/playlis...
# 3  https://g1.globo.com/podcast/o-assunto/ao-vivo...
# 4  https://g1.globo.com/podcast/o-assunto/noticia...
# 5  https://g1.globo.com/politica/eleicoes/2022/vi...
# 6  https://g1.globo.com/politica/eleicoes/2022/vi...
# 7  https://g1.globo.com/politica/eleicoes/2022/vi...
# 8  https://g1.globo.com/fato-ou-fake/sao-paulo/no...
# 9  https://g1.globo.com/politica/eleicoes/2022/vi...
#
#                          date  \
# 0  2024-08-08 14:56:48.748918
# 1         2024-08-05 14:54:00
# 2         2024-08-05 21:23:00
# 3         2024-08-05 18:40:00
# 4         2024-08-05 21:38:00
# 5         2024-08-05 14:17:00
# 6         2024-08-05 15:28:00
# 7         2024-08-06 15:22:00
# 8         2024-08-06 00:13:00
# 9         2024-08-05 15:38:00
#
#                                          description  \
# 0  O Assunto: Natuza Nery entrevistaTabataAmaral(...
# 1  Série do g1 começa na segunda (5) com a candid...
# 2
# 3  Natuza Nery entrevistaTabataAmaral(PSB) Esta s...
# 4  ... sobre traição de DatenaTabataAmaralanuncia...
# 5  Série do g1 começa na segunda (5) com a candid...
# 6  Série do g1 começa na segunda (5) com a candid...
# 7  Série do g1 começou na segunda (5) comTabataAm...
# 8  TabataAmaral(PSB), candidata à Prefeitura de S...
# 9  Série do g1 começa na segunda (5) com a candid...
#
#                                            full_text
# 0   A deputada federal Tabata Amaral, candidata à...
# 1
# 2
# 3
# 4   Você pode ouvir O Assunto no g1, no GloboPlay...
# 5
# 6
# 7
# 8   A deputada federal Tabata Amaral, candidata à...
# 9

# %%
articles = fetch_g1_news('Guilherme Boulos', num_articles=20)
articles
# Out:
#                                                 title  \
# 0   O Assunto #1273: Natuza Nery entrevista Guilhe...
# 1   Natuza Nery entrevista Guilherme Boulos (PSOL)...
# 2   Veja o que é #FATO ou #FAKE na entrevista de G...
# 3   Datafolha: veja intenção de voto em possível 2...
# 4   Datafolha: Boulos (35%), Datena (31%) e Marçal...
# 5   Justiça ordena pela 2ª vez que Marçal apague i...
# 6   Eleições 2024 em São Paulo: Ricardo Nunes tem ...
# 7   Eleições 2024: confira raio-X dos principais p...
# 8   Resumão diário #1048: Ex-executivos das Lojas ...
# 9                   O Assunto entrevista João Pimenta
# 10  Ao g1, João Pimenta defende extinção da GCM e ...
# 11  Raquel Lyra e Guilherme Boulos se reúnem em Br...
# 12  Veja quais candidatos à Prefeitura de SP estão...
# 13  Datafolha: confira intenção de voto para Prefe...
# 14  Veja a lista dos patrimônios dos candidatos à ...
# 15  Como estão as corridas eleitorais em BH, Campo...
# 16  Veja a lista dos patrimônios dos candidatos à ...
# 17                O Assunto entrevista Ricardo Senese
# 18                O Assunto entrevista Bebetto Haddad
# 19                 O Assunto entrevista Marina Helena
#
#                                                  link  \
# 0   https://g1.globo.com/podcast/o-assunto/noticia...
# 1   https://g1.globo.com/sp/sao-paulo/eleicoes/202...
# 2   https://g1.globo.com/fato-ou-fake/sao-paulo/no...
# 3   https://g1.globo.com/sp/sao-paulo/eleicoes/202...
# 4   https://g1.globo.com/sp/sao-paulo/eleicoes/202...
# 5   https://g1.globo.com/sp/sao-paulo/eleicoes/202...
# 6   https://g1.globo.com/sp/sao-paulo/eleicoes/202...
# 7   https://g1.globo.com/sp/sao-paulo/noticia/2024...
# 8   https://g1.globo.com/podcast/resumao-diario/no...
# 9   https://g1.globo.com/podcast/o-assunto/noticia...
# 10  https://g1.globo.com/sp/sao-paulo/eleicoes/202...
# 11  https://g1.globo.com/pe/pernambuco/eleicoes/20...
# 12  https://g1.globo.com/sp/sao-paulo/eleicoes/202...
# 13  https://g1.globo.com/sp/sao-paulo/eleicoes/202...
# 14  https://g1.globo.com/sp/sao-paulo/eleicoes/202...
# 15  https://g1.globo.com/politica/eleicoes/2024/pe...
# 16  https://g1.globo.com/sp/sao-paulo/eleicoes/202...
# 17  https://g1.globo.com/podcast/o-assunto/noticia...
# 18  https://g1.globo.com/podcast/o-assunto/noticia...
# 19  https://g1.globo.com/podcast/o-assunto/noticia...
#
#                           date  \
# 0   2024-08-08 19:55:22.022866
# 1   2024-08-08 19:55:22.023088
# 2   2024-08-08 19:55:22.023174
# 3   2024-08-06 19:55:22.023241
# 4   2024-08-09 19:55:22.023303
# 5   2024-08-06 19:55:22.023364
# 6          2024-07-05 20:10:00
# 7   2024-08-08 19:55:22.023600
# 8          2024-06-27 13:19:00
# 9   2024-08-12 19:55:22.023741
# 10  2024-08-09 19:55:22.023803
# 11         2024-05-10 21:40:00
# 12         2024-08-01 22:59:00
# 13  2024-08-12 19:55:22.024009
# 14  2024-08-10 19:55:22.024094
# 15         2024-08-06 09:32:00
# 16  2024-08-06 19:55:22.024260
# 17  2024-08-09 19:55:22.024322
# 18  2024-08-09 19:55:22.024382
# 19  2024-08-09 19:55:22.024442
#
#                                           description  \
# 0   ...GuilhermeBoulos(PSOL) em entrevista ao g1, ...
# 1   O Assunto: Natuza Nery entrevistaGuilhermeBoul...
# 2   GuilhermeBoulos(PSOL) em entrevista ao g1, nes...
# 3   O prefeito de São Paulo, Ricardo Nunes (MDB), ...
# 4   ...-feira (8) aponta queGuilhermeBoulos(PSOL),...
# 5   Os candidatos à Prefeitura de SP Pablo Marçal ...
# 6   .... Na sequência, estãoGuilhermeBoulos(PSOL),...
# 7   ... dos primeiros colocados segundo a última p...
# 8   ... bilhões. Eleições 2024 em São Paulo: Ricar...
# 9   ... e não apoiarGuilhermeBoulos(PSOL), João di...
# 10  ... dos profissionais e melhorar a infraestrut...
# 11  Raquel Lyra (PSDB) eGuilhermeBoulos(PSOL)\nTV ...
# 12  ... Paulo em outubro.\nEm 20 de julho, o PSOL ...
# 13  O deputado federalGuilhermeBoulos(PSOL) e o pr...
# 14  ... registrados pelo Tribunal Superior Eleitor...
# 15  ... na liderança entre o prefeito Ricardo Nune...
# 16  ... registrados pelo Tribunal Superior Eleitor...
# 17  ...: Tabata Amaral (PSB), José Luiz Datena (PS...
# 18  ... na pesquisa Quaest publicada em 30 de julh...
# 19  ...),GuilhermeBoulos(Psol), Pablo Marçal (PRTB...
#
#                                             full_text         candidate
# 0    Você pode ouvir O Assunto no g1, no GloboPlay...  Guilherme+Boulos
# 1    Guilherme Boulos, candidato à Prefeitura de S...  Guilherme+Boulos
# 2    O deputado federal Guilherme Boulos, candidat...  Guilherme+Boulos
# 3    Pesquisa Datafolha divulgada nesta terça-feir...  Guilherme+Boulos
# 4    Pesquisa Datafolha desta quinta (8) mostra qu...  Guilherme+Boulos
# 5    O Tribunal Regional Eleitoral de SP (TRE-SP) ...  Guilherme+Boulos
# 6    Pesquisa Quaest divulgada nesta quinta-feira ...  Guilherme+Boulos
# 7    Apesar de convenções partidárias - que aconte...  Guilherme+Boulos
# 8    Você pode ouvir o Resumão Diário no g1, no Gl...  Guilherme+Boulos
# 9    Você pode ouvir O Assunto no g1, no GloboPlay...  Guilherme+Boulos
# 10   João Pimenta, candidato do Partido da Causa O...  Guilherme+Boulos
# 11   A governadora de Pernambuco, Raquel Lyra (PSD...  Guilherme+Boulos
# 12   O período de convenções partidárias, momento ...  Guilherme+Boulos
# 13   Pesquisa Datafolha divulgada nesta segunda-fe...  Guilherme+Boulos
# 14   Os candidatos à Prefeitura de São Paulo têm a...  Guilherme+Boulos
# 15   A Quaest divulgou em julho pesquisas de inten...  Guilherme+Boulos
# 16   Os candidatos à Prefeitura de São Paulo têm a...  Guilherme+Boulos
# 17   Você pode ouvir O Assunto no g1, no GloboPlay...  Guilherme+Boulos
# 18   Você pode ouvir O Assunto no g1, no GloboPlay...  Guilherme+Boulos
# 19   Você pode ouvir O Assunto no g1, no GloboPlay...  Guilherme+Boulos
